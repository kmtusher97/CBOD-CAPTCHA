# %%
import os
import random
import numpy as np
import pandas as pd

# %%
images_df = pd.read_csv('./data/image_data.csv')
images_df.head()
# Out:
#    id        file_name   category
# 0   0  img-000000.jpeg     parrot
# 1   1  img-000001.jpeg       crow
# 2   2  img-000002.jpeg  sunflower
# 3   3  img-000003.jpeg     parrot
# 4   4  img-000004.jpeg       crow

# %%
n = 4 # select four random images
images_data = np.array(images_df)

images_ar = images_data[np.random.choice(len(images_data), n, replace = False)]
images_ar
# Out:
# array([[4, 'img-000004.jpeg', 'crow'],
#        [6, 'img-000006.jpeg', 'crow'],
#        [0, 'img-000000.jpeg', 'parrot'],
#        [7, 'img-000007.jpeg', 'sunflower']], dtype=object)

# %%
from PIL import Image

# %%
images = [Image.open('./images/' + img[1]) for img in images_ar]

for image in images:
    display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F0D827C2B70>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F0D827D40F0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F0D827D40B8>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=100x100 at 0x7F0D827D4198>

# %%
image_size = images[0].size
print('image size: ', image_size)

merged_image = Image.new('RGB',(2 * image_size[0], 2 * image_size[1]), (250,250,250))
display(merged_image)
# Out:
# image size:  (100, 100)
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F0D827EA208>

# %%
merged_image.paste(images[0], (0, 0))
display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F0D827EA208>

# %%
coords = [(0, 0), (image_size[0], 0), (0, image_size[1]), image_size]
for i in range(4):
    merged_image.paste(images[i], coords[i])

display(merged_image)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F0D827EA208>
